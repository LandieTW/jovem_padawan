# %%
# %pip install pytest
# !pip install pytest
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import pytest

# %%
change_dir = r"C:\Users\landi\Downloads\github\jovem_padawan\pytest\test_ex.py"

# %%
# test 1

# !pytest {change_dir} -k "somefunc" -v
# !pytest {change_dir} -k test_somefunction -v --junitxml="tests_results.xml"

# !pytest {change_dir} -k "test_test" -v
# !pytest {change_dir} -k test_test_otherfunction -v --maxfail 3

# !pytest {change_dir} -k "otherfunc" -v

# !pytest {change_dir} -k pair_numbers -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\Users\landi\AppData\Local\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\landi\Downloads\github\jovem_padawan\pytest
# configfile: pytest.ini
# plugins: anyio-4.10.0
# collecting ... collected 6 items / 5 deselected / 1 selected
#
# test_ex.py::test_somefunction PASSED                                     [100%]
#
# ======================= 1 passed, 5 deselected in 0.06s =======================
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\Users\landi\AppData\Local\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\landi\Downloads\github\jovem_padawan\pytest
# configfile: pytest.ini
# plugins: anyio-4.10.0
# collecting ... collected 6 items / 5 deselected / 1 selected
#
# ...
